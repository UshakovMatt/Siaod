# %%
#Лабораторная работа №1
#Выполнил студент группы БВТ2001 Ушаков Матвей 
#Задание №1

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
import time
import random

def rand_mat(m=50, n=50, min_limit=-250, max_limit=1023):
    return [[random.randint(min_limit, max_limit) for _ in range(n)] for _ in range(m)]

def select_sort(arr):#выборка
    for i, e in enumerate(arr):
        mIn = min(range(i, len(arr)), key=arr.__getitem__)
        arr[i], arr[mIn] = arr[mIn], e
    return arr

#вставка
def insert_sort(arr):
    for i in range(1, len(arr)):
        j = i - i
        while j >= 0 and arr[i] < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = arr[i]
        
#обменом
def bub_sort(arr):
    for i in range(len(arr)):
        for j in range(0, len(arr)-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                
#быстрая
def quick_sort(arr, lst=None, fst=0): 
    if lst == None:
        lst = len(arr) - 1

    if fst >= lst:
        return

    i, j = lst, fst
    sot = arr[(lst + fst) // 2]

    while i <= j:
        while arr[i] < sot:
            i += 1
        while arr[j] > sot:
            j -= 1
        if i <= j:
            arr[i], arr[j] = arr[j], arr[i]
            i, j = i + 1, j - 1

    quick_sort(arr, fst, j)
    quick_sort(arr, i, lst)
    
#турнирная
def tournament_sort(arr):
    tree = [None] * 2 * (len(arr) + len(arr) % 2)
    index = len(tree) - len(arr) - len(arr) % 2

    for i, e in enumerate(arr):
        tree[index + i] = (i, e)

    for j in range(len(arr)):
        n = len(arr)
        index = len(tree) - len(arr) - len(arr) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1) # на последней итерация index + i * 2 = 0
                if tree[i] != None and tree[i + 1] != None:
                    if tree[i][1] < tree[i + 1][1]:
                        tree[i // 2] = tree[i]
                    else:
                        tree[i // 2] = tree[i + 1]
                else:
                    tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
            index -= n

        index, x = tree[0]
        arr[j] = x
        tree[len(tree) - len(arr) - len(arr) % 2 + index] = None
        
#шелла
def shell_sort(arr):
    last_index = len(arr) - 1
    step = len(arr) // 2
    while step > 0:
        for i in range(step, last_index + 1, 1):
            j = i
            Del = j - step
            while Del >= 0 and arr[Del] > arr[j]:
                arr[Del], arr[j] = arr[j], arr[Del]
                j = Del
                Del = j - step
        step //= 2        
        
#пирамидальная
def heapify(arr,n,i):# i - корневой узел, n - размер кучи, преобразовываем в двоичную кучу для поддерева с корневым узлом
    largest = i 
    l = 2 * i + 1
    r = 2 * i + 2
    #проверяем есть ли левый элемент больший корня
    if l < n and arr[i] < arr[l]:
        largest = l
    #проверяем есть ли правый элемент больший корня 
    if r < n and arr[largest] < arr[r]:
        largest = r
    #заменяем корень, если потребуется
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i] #свапаем
        #применяем heapify к корню
        heapify(arr, n, largest)
#основная функция для сортировки
def heap_sort(arr):
    n = len(arr)
    #строим max_heap
    for i in range(n , -1, -1):
        heapify(arr, n , i)
    #и теперь извлекаем элементы друг за другом
    for i in range(n-1, 0 , -1):
        arr[i], arr[0] = arr[0], arr[i]#свапаем
        heapify(arr, i, 0)

        
        
        
SORT_FUNCTIONS = {
    'выборка': select_sort,
    'вставка': insert_sort,
    'обменом': bub_sort,
    'быстрая': quick_sort,
    'турнирная': tournament_sort,
    'шелла': shell_sort,
    'обменом': bub_sort,
    'Пирамидальная': heap_sort,
    'Встроенная сортирока': sorted
}

def print_comparison(comparison):
    largest_name_len = len(max(comparison.keys(), key=len))
    largest_name_len += 6

    heading = 'Алгоритм'.ljust(largest_name_len) + 'Время'
    print(heading)
    print('-' * len(heading))
    for algo, time_taken in comparison.items():
        print(f'{algo:<{largest_name_len}}{time_taken}')

time_taken = {}
samples = rand_mat(50, 1000)
for algo_name, sorter in SORT_FUNCTIONS.items():
    samples_copy = samples.copy()
    start = time.perf_counter()
    for sample in samples_copy:
        sorter(sample)
    end = time.perf_counter()

    time_taken[algo_name] = (end - start) / len(samples)

time_taken_sorted = dict(sorted(time_taken.items(), key=lambda kv: kv[1]))
print_comparison(time_taken_sorted)
# Out:
# Алгоритм                  Время
# -------------------------------
# быстрая                   8.941600026446394e-07
# Встроенная сортирока      7.717500002399902e-06
# вставка                   0.0001530583400017349
# шелла                     0.0008982700000024124
# Пирамидальная             0.00393686500000058
# выборка                   0.02170746415999929
# обменом                   0.04153414916000202
# турнирная                 0.4034977291799987
